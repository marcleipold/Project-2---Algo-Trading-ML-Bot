# %%
# !pip install vaderSentiment

import tweepy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import pandas as pd

# set up Twitter API credentials
consumer_key = '9uZbJLS4xVltumTOS0SlnMghf'
consumer_secret = 'w2hC49P6LLRm1DtdCmdT6BCinM2YyAcSKpsJwraDqlaO8SOPkW'
access_token = '946010273839755264-eNJNnKdn08jfq2S7rVl9lFgUQ3nuL3e'
access_token_secret = '7j69ROBqlSMunJXu8W8XXJZtldWHMhXLmA2XT2umIR43m'

# %%
# initialize tweepy and vader
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
vader = SentimentIntensityAnalyzer()

# %%
api.search_tweets
# Out:
# <bound method API.search_tweets of <tweepy.api.API object at 0x00000143E311CC40>>

# %%
# get tweets
tweets = api.search_tweets(q="BTCUSD", count=50000)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\Users\marcl\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Users\marcl\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# c:\Users\marcl\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     336         context.verify_mode = resolve_cert_reqs(self.cert_reqs)
# --> 337         self.sock = ssl_wrap_socket(
#     338             sock=conn,
#
# ...

# %%
keyword, start, end

# %%
sentiment_list = []
tweet_list = []

# %%
# perform sentiment analysis
for tweet in tweets:
    tweet_text = tweet.text
    sentiment = vader.polarity_scores(tweet_text)["compound"]
    print("Tweet:", tweet_text)
    print("Sentiment:", sentiment)
    print("\n")
# Out:
# Tweet: 🇹🇷 𝐌𝐀𝐑𝐊𝐄𝐓 𝐒𝐔𝐌𝐌𝐀𝐑𝐘:
# 🟩 USD: 18,83 TRY %0,0
# 🟩 EUR: 20,22 TRY %0,1
# 🟩 GBP: 22,69 TRY %0,3
# 🟩 GRAM ALTIN: 1.133,99 TRY %0,… https://t.co/ltnOVMYoAo
# Sentiment: 0.0
#
#
# Tweet: Indicative price bands from BitVol &amp; LXVX
#
# BTCUSD: $22,829
# BitVol: 58.88
# 　【Day】$22062 ～ $23466
# 　【Week】$20905 ～ $246… https://t.co/PSLJZP9iTn
# Sentiment: 0.0
#
#
# Tweet: BTC Outlook https://t.co/Yn840kXbtE 📈📉💹📊 ⟶ via https://t.co/lsTr6NEvET https://t.co/XKiG8PBYPv
# Sentiment: 0.0
#
#
# Tweet: Thoughts on $BTC #Bitcoin! See miladchikol's idea on TradingView below. https://t.co/fbRIDSyXVr
# Sentiment: 0.0
#
#
# Tweet: + 　0回
# -　  4回
#
# USD/JPY &amp; BTCUSD = +20.02
# Balance =2,350.39（過去最高比2,423.58：97.0%）
#
# どうも思う様にいきません。（笑）
# 損切りラインが高いので頻繁に喰らいま… https://t.co/U4F7kr6F7o
# Sentiment: 0.0
#
#
# Tweet: 🇹🇷 𝐌𝐀𝐑𝐊𝐄𝐓 𝐒𝐔𝐌𝐌𝐀𝐑𝐘:
# 🟩 USD: 18,83 TRY %0,0
# 🟩 EUR: 20,22 TRY %0,1
# 🟩 GBP: 22,69 TRY %0,3
# 🟩 GRAM ALTIN: 1.133,72 TRY %0,… https://t.co/psSpm4zsUq
# Sentiment: 0.0
#
#
# ...

# %%
sentiment
# Out:
# 0.0
